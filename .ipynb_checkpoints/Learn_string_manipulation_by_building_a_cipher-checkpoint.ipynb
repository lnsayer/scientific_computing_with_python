# %%
text = ' world how are you doing today'
custom_key = 'happycoding'

def vigenere(message, key, direction=1):
    key_index = 0
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    final_message = ''

    for char in message.lower():

        # Append any non-letter character to the message
        if not char.isalpha():
            final_message += char
        else:        
            # Find the right key character to encode/decode
            key_char = key[key_index % len(key)]
            print(f"key_char {key_char}, key_index {key_index}, len(key) {len(key)}, key_index%len(key) {key_index%len(key)}")
            key_index += 1

            # Define the offset and the encrypted/decrypted letter
            offset = alphabet.index(key_char)
            print(f"offset {offset}")
            index = alphabet.find(char)
            print(f"index {index}")
            new_index = (index + offset*direction) % len(alphabet)
            print(f"new index {new_index}")
            final_message += alphabet[new_index]
            print(final_message)
    
    return final_message

def encrypt(message, key):
    return vigenere(message, key)
    
def decrypt(message, key):
    return vigenere(message, key, -1)

print(encrypt(text, custom_key))

# print(f'\nEncrypted text: {text}')
# print(f'Key: {custom_key}')
# decryption = decrypt(text, custom_key)
# print(f'\nDecrypted text: {decryption}\n')
# Out:
# key_char h, key_index 0, len(key) 11, key_index%len(key) 0
# offset 7
# index 22
# new index 3
#  d
# key_char a, key_index 1, len(key) 11, key_index%len(key) 1
# offset 0
# index 14
# new index 14
#  do
# key_char p, key_index 2, len(key) 11, key_index%len(key) 2
# offset 15
# index 17
# new index 6
#  dog
# key_char p, key_index 3, len(key) 11, key_index%len(key) 3
# offset 15
# index 11
# new index 0
#  doga
# key_char y, key_index 4, len(key) 11, key_index%len(key) 4
# offset 24
# index 3
# new index 1
#  dogab
# key_char c, key_index 5, len(key) 11, key_index%len(key) 5
# offset 2
# index 7
# new index 9
#  dogab j
# key_char o, key_index 6, len(key) 11, key_index%len(key) 6
# offset 14
# index 14
# new index 2
#  dogab jc
# key_char d, key_index 7, len(key) 11, key_index%len(key) 7
# offset 3
# index 22
# new index 25
#  dogab jcz
# key_char i, key_index 8, len(key) 11, key_index%len(key) 8
# offset 8
# index 0
# new index 8
#  dogab jcz i
# key_char n, key_index 9, len(key) 11, key_index%len(key) 9
# offset 13
# index 17
# new index 4
#  dogab jcz ie
# key_char g, key_index 10, len(key) 11, key_index%len(key) 10
# offset 6
# index 4
# new index 10
#  dogab jcz iek
# key_char h, key_index 11, len(key) 11, key_index%len(key) 0
# offset 7
# index 24
# new index 5
#  dogab jcz iek f
# key_char a, key_index 12, len(key) 11, key_index%len(key) 1
# offset 0
# index 14
# new index 14
#  dogab jcz iek fo
# key_char p, key_index 13, len(key) 11, key_index%len(key) 2
# offset 15
# index 20
# new index 9
#  dogab jcz iek foj
# key_char p, key_index 14, len(key) 11, key_index%len(key) 3
# offset 15
# index 3
# new index 18
#  dogab jcz iek foj s
# key_char y, key_index 15, len(key) 11, key_index%len(key) 4
# offset 24
# index 14
# new index 12
#  dogab jcz iek foj sm
# key_char c, key_index 16, len(key) 11, key_index%len(key) 5
# offset 2
# index 8
# new index 10
#  dogab jcz iek foj smk
# key_char o, key_index 17, len(key) 11, key_index%len(key) 6
# offset 14
# index 13
# new index 1
#  dogab jcz iek foj smkb
# key_char d, key_index 18, len(key) 11, key_index%len(key) 7
# offset 3
# index 6
# new index 9
#  dogab jcz iek foj smkbj
# key_char i, key_index 19, len(key) 11, key_index%len(key) 8
# offset 8
# index 19
# new index 1
#  dogab jcz iek foj smkbj b
# key_char n, key_index 20, len(key) 11, key_index%len(key) 9
# offset 13
# index 14
# new index 1
#  dogab jcz iek foj smkbj bb
# key_char g, key_index 21, len(key) 11, key_index%len(key) 10
# offset 6
# index 3
# new index 9
#  dogab jcz iek foj smkbj bbj
# key_char h, key_index 22, len(key) 11, key_index%len(key) 0
# offset 7
# index 0
# new index 7
#  dogab jcz iek foj smkbj bbjh
# key_char a, key_index 23, len(key) 11, key_index%len(key) 1
# offset 0
# index 24
# new index 24
#  dogab jcz iek foj smkbj bbjhy
#  dogab jcz iek foj smkbj bbjhy
